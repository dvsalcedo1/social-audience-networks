# %%
import networkx as nx
import pandas as pd

# %%
# Each row in links_final shows how a linker relates to another linker based on how many shared sources they have
filename_base = "fbh2_ct_scan_2016-processed-shared-sources"
links_final = pd.read_csv(f"results/{filename_base}-links.csv")
links_final = links_final[ links_final['link'] >= 4 ]
links_final
# Out:
#                                           site1  \
# 0       www.facebook.com/groups/538773259559791
# 1       www.facebook.com/groups/538773259559791
# 2      www.facebook.com/groups/1016387625038290
# 3       www.facebook.com/groups/308734279321570
# 4       www.facebook.com/groups/308734279321570
# ...                                         ...
# 13320  www.facebook.com/groups/1695807327318825
# 13321   www.facebook.com/groups/287398064766941
# 13322  www.facebook.com/groups/1695807327318825
# 13323  www.facebook.com/groups/1695807327318825
# 13324  www.facebook.com/groups/1695807327318825
#
#                                           site2  link
# 0      www.facebook.com/groups/1016387625038290   138
# 1       www.facebook.com/groups/308734279321570   137
# 2       www.facebook.com/groups/859836347426689    98
# 3      www.facebook.com/groups/1016387625038290    95
# 4       www.facebook.com/groups/505037502920274    75
# ...                                         ...   ...
# 13320  www.facebook.com/groups/1749764535277188     4
# 13321   www.facebook.com/groups/365684020289315     4
# 13322   www.facebook.com/groups/669427883158907     4
# 13323   www.facebook.com/groups/663999290411287     4
# 13324   www.facebook.com/groups/199173430125312     4
#
# [13325 rows x 3 columns]

# %%
# See the link size distribution
import plotly.express as px
fig = px.histogram(links_final, x="link")
fig.show()

# %%
# Community detection algorithm that assigns a community to each linker
G = nx.Graph()
for i in links_final.index.tolist():
    source = links_final.at[i,'site1']
    dest = links_final.at[i,'site2']
    edge_size = links_final.at[i,'link']
    G.add_edge(source,dest, weight=edge_size)

from networkx import edge_betweenness_centrality as betweenness
def most_central_edge(G):
    centrality = betweenness(G, weight="weight")
    return max(centrality, key=centrality.get)
    
comp = nx.algorithms.community.centrality.girvan_newman(G, most_valuable_edge=most_central_edge)
communities = tuple(sorted(c) for c in next(comp))

# %%
# Checking how many linkers per community
for i in communities:
    print(len(i))
# Out:
# 524
# 61
# 11
# 4
# 2
# 5
# 2
# 2

# %%
# Tag each node with its respective community
for i in range(len(communities)):
    for node in communities[i]:
        G.nodes[node]['name'] = node
        G.nodes[node]['comm'] = i

# %%
# Roots is a reference table for each linker, providing more info about each linker
roots = pd.read_csv(f"results/{filename_base}-nodes.csv")
roots
# Out:
#                                          index  connectors  \
# 0      www.facebook.com/groups/538773259559791      2062.0
# 1      www.facebook.com/groups/308734279321570      1130.0
# 2     www.facebook.com/groups/1016387625038290      1024.0
# 3      www.facebook.com/groups/859836347426689       443.0
# 4      www.facebook.com/groups/505037502920274       376.0
# ...                                        ...         ...
# 2564  www.facebook.com/groups/1563625567284575         2.0
# 2565              www.facebook.com/NamoKeralam         2.0
# 2566              www.facebook.com/marendorser         2.0
# 2567   www.facebook.com/groups/422286841202782         2.0
# 2568             www.facebook.com/navhindtimes         2.0
#
#                                     linker_name linker_type  \
# 0     PHILIPPINE FEDERAL MOVEMENT INTERNATIONAL       group
# 1                       Freedom Wall (original)       group
# 2                 SARA DUTERTE SOLID SUPPORTERS       group
# 3         (vf)DDS/ DIEHARD  DUTERTE  SUPPORTERS       group
# 4                          Gising Na Pilipinas!       group
# ...                                         ...         ...
# 2564                         Youth BJP , Odisha       group
# 2565                               NAMO Keralam        page
# 2566          Filipinos Endorsing Marcos A HERO        page
# 2567       BLF Inc. - Batang Licab Forever Inc.       group
# 2568                          The Navhind Times        page
#
#                                     linker_url
# 0      www.facebook.com/groups/538773259559791
# 1      www.facebook.com/groups/308734279321570
# 2     www.facebook.com/groups/1016387625038290
# 3      www.facebook.com/groups/859836347426689
# 4      www.facebook.com/groups/505037502920274
# ...                                        ...
# 2564  www.facebook.com/groups/1563625567284575
# 2565              www.facebook.com/NamoKeralam
# 2566              www.facebook.com/marendorser
# 2567   www.facebook.com/groups/422286841202782
# 2568             www.facebook.com/navhindtimes
#
# [2569 rows x 5 columns]

# %%
# Add a 'community' column to the roots table to include the tagged community of each node. If the linker has no tagged community,
# we tag it with '99', or no perceived community
roots = roots.set_index('index')
for root in roots.index.tolist():
    try:
        roots.at[root,'community'] = str(G.nodes[root]['comm'])
    except:
        roots.at[root,'community'] = str(99)

# %%
roots
# Out:
#                                           connectors  \
# index
# www.facebook.com/groups/538773259559791       2062.0
# www.facebook.com/groups/308734279321570       1130.0
# www.facebook.com/groups/1016387625038290      1024.0
# www.facebook.com/groups/859836347426689        443.0
# www.facebook.com/groups/505037502920274        376.0
# ...                                              ...
# www.facebook.com/groups/1563625567284575         2.0
# www.facebook.com/NamoKeralam                     2.0
# www.facebook.com/marendorser                     2.0
# www.facebook.com/groups/422286841202782          2.0
# www.facebook.com/navhindtimes                    2.0
#
#                                                                         linker_name  \
# index
# www.facebook.com/groups/538773259559791   PHILIPPINE FEDERAL MOVEMENT INTERNATIONAL
# www.facebook.com/groups/308734279321570                     Freedom Wall (original)
# www.facebook.com/groups/1016387625038290              SARA DUTERTE SOLID SUPPORTERS
# www.facebook.com/groups/859836347426689       (vf)DDS/ DIEHARD  DUTERTE  SUPPORTERS
# www.facebook.com/groups/505037502920274                        Gising Na Pilipinas!
# ...                                                                             ...
# www.facebook.com/groups/1563625567284575                         Youth BJP , Odisha
# www.facebook.com/NamoKeralam                                           NAMO Keralam
# www.facebook.com/marendorser                      Filipinos Endorsing Marcos A HERO
# www.facebook.com/groups/422286841202782        BLF Inc. - Batang Licab Forever Inc.
# www.facebook.com/navhindtimes                                     The Navhind Times
#
#                                          linker_type  \
# index
# www.facebook.com/groups/538773259559791        group
# www.facebook.com/groups/308734279321570        group
# www.facebook.com/groups/1016387625038290       group
# www.facebook.com/groups/859836347426689        group
# www.facebook.com/groups/505037502920274        group
# ...                                              ...
# www.facebook.com/groups/1563625567284575       group
# www.facebook.com/NamoKeralam                    page
# www.facebook.com/marendorser                    page
# www.facebook.com/groups/422286841202782        group
# www.facebook.com/navhindtimes                   page
#
#                                                                         linker_url  \
# index
# www.facebook.com/groups/538773259559791    www.facebook.com/groups/538773259559791
# www.facebook.com/groups/308734279321570    www.facebook.com/groups/308734279321570
# www.facebook.com/groups/1016387625038290  www.facebook.com/groups/1016387625038290
# www.facebook.com/groups/859836347426689    www.facebook.com/groups/859836347426689
# www.facebook.com/groups/505037502920274    www.facebook.com/groups/505037502920274
# ...                                                                            ...
# www.facebook.com/groups/1563625567284575  www.facebook.com/groups/1563625567284575
# www.facebook.com/NamoKeralam                          www.facebook.com/NamoKeralam
# www.facebook.com/marendorser                          www.facebook.com/marendorser
# www.facebook.com/groups/422286841202782    www.facebook.com/groups/422286841202782
# www.facebook.com/navhindtimes                        www.facebook.com/navhindtimes
#
#                                          community
# index
# www.facebook.com/groups/538773259559791          0
# www.facebook.com/groups/308734279321570          0
# www.facebook.com/groups/1016387625038290         0
# www.facebook.com/groups/859836347426689          0
# www.facebook.com/groups/505037502920274          0
# ...                                            ...
# www.facebook.com/groups/1563625567284575        99
# www.facebook.com/NamoKeralam                    99
# www.facebook.com/marendorser                    99
# www.facebook.com/groups/422286841202782         99
# www.facebook.com/navhindtimes                   99
#
# [2569 rows x 5 columns]

# %%
roots.to_csv(f'results/{filename_base}-nodes-tagged.csv')

# %% [markdown]
# # Who are these roots sharing from?
# We turn our attention to community 0 and community 3, since these are the largest tagged communities of linkers

# %%
# Master is the complete list of posts. For each post, we get the source and linker
master = pd.read_csv(
    f"data/{filename_base[:-15]}.csv",
    usecols=["linker_name","linker_type","linker_url","source_name","source_type","source_url"],
    dtype=str
)
master.head()
# Out:
#   linker_type              linker_name                        linker_url  \
# 0        page                  ABS-CBN    www.facebook.com/ABSCBNnetwork
# 1        page                 GMA News          www.facebook.com/gmanews
# 2        page  PSSAP Underground Media  www.facebook.com/526965450801338
# 3        page          MOCHA USON BLOG     www.facebook.com/Mochablogger
# 4        page          MOCHA USON BLOG     www.facebook.com/Mochablogger
#
#         source_type                source_name  \
# 0  external website  entertainment.abs-cbn.com
# 1  external website         www.gmanetwork.com
# 2          facebook            526965450801338
# 3          facebook               Mochablogger
# 4          facebook               Mochablogger
#
#                          source_url
# 0         entertainment.abs-cbn.com
# 1                www.gmanetwork.com
# 2  www.facebook.com/526965450801338
# 3     www.facebook.com/Mochablogger
# 4     www.facebook.com/Mochablogger

# %%
# Alias for communities to be observed
global_tags = {
    '0': 'comm_0',
    '1': 'comm_1'
}

# %%
# For each community of linkers, get the posts in master that contain these linkers.
# Root sources is then a dictionary with keys equal to the observed communities (i.e. keys in global tags)
# Each value in root sources is a dataframe of every unique source that the linkers of that community have sahred from.
# The sharers column shows how many linkers shared from that source. This column is specific to the community 
# (i.e. if Source X is shared 40 times in community 0 and 20 times in community 1, it will appear twice and the sharers column will show 40 and 20, respectively)
root_sources = {}
for i in global_tags.keys():
    roots_i = roots[roots['community'] == i].reset_index()
    root_sources[i] = (
        pd
        .merge(
            master,
            roots_i,
            left_on='linker_url',
            right_on='linker_url',
            how='inner'
        )
        .groupby('source_url')
        .agg(
            Sharers=('source_url','count'),
            Name=('source_name','first'),
            Type=('source_type','first')
        )
        .sort_values(by='Sharers',ascending=False)
        .reset_index()
    )
    root_sources[i]['community'] = [i]*len(root_sources[i])

# %%
# Concatenate all dataframes from the previous cell
root_sources_concat = pd.concat([root_sources[i] for i in root_sources.keys()])
root_sources_concat
# Out:
#                                             source_url  Sharers  \
# 0                       www.facebook.com/rapplerdotcom      771
# 1                        www.facebook.com/Mochablogger      657
# 2                     www.facebook.com/526965450801338      648
# 3                                     news.abs-cbn.com      612
# 4                                      www.rappler.com      600
# ..                                                 ...      ...
# 445                   www.facebook.com/530767340283701        1
# 446                   www.facebook.com/533311433442726        1
# 447                   www.facebook.com/615880665179442        1
# 448  https://www.facebook.com/photo.php?fbid=282761...        1
# 449                                       agniveer.com        1
#
#                                                   Name              Type  \
# 0                                        rapplerdotcom          facebook
# 1                                         Mochablogger          facebook
# 2                                      526965450801338          facebook
# 3                                     news.abs-cbn.com  external website
# 4                                      www.rappler.com  external website
# ..                                                 ...               ...
# 445                                    530767340283701          facebook
# 446                                    533311433442726          facebook
# 447                                    615880665179442          facebook
# 448  Facebook profile: Photos from Omaram Choudhary...          facebook
# 449                                       agniveer.com  external website
#
#     community
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ..        ...
# 445         1
# 446         1
# 447         1
# 448         1
# 449         1
#
# [2818 rows x 5 columns]

# %%
root_sources_concat.to_csv(f"results/{filename_base}-by-community.csv",index=False)

# %% [markdown]
# # Label sources and linkers

# %%
# Get all the unique sources from master
sources = master.drop_duplicates(subset=['source_url'])[["source_name","source_type","source_url"]]
sources
# Out:
#                         source_name       source_type  \
# 0         entertainment.abs-cbn.com  external website
# 1                www.gmanetwork.com  external website
# 2                   526965450801338          facebook
# 3                      Mochablogger          facebook
# 6      pinoytrending.altervista.org  external website
# ...                             ...               ...
# 40424                       PRO7PNP          facebook
# 40447     www.westernjournalism.com  external website
# 40449           www.navhindtimes.in  external website
# 40451          ktsmradio.iheart.com  external website
# 40467                  304981108326          facebook
#
#                              source_url
# 0             entertainment.abs-cbn.com
# 1                    www.gmanetwork.com
# 2      www.facebook.com/526965450801338
# 3         www.facebook.com/Mochablogger
# 6          pinoytrending.altervista.org
# ...                                 ...
# 40424          www.facebook.com/PRO7PNP
# 40447         www.westernjournalism.com
# 40449               www.navhindtimes.in
# 40451              ktsmradio.iheart.com
# 40467     www.facebook.com/304981108326
#
# [7357 rows x 3 columns]

# %%
# Assign a final community (color) to each source, use root_sources_concat as the reference table
# y = only in community 0
# b = only in community 1
# g = both in community 0 and 1
# w = no community
for i in sources.index.tolist():
    numComms = root_sources_concat[ root_sources_concat['source_url'] == sources.at[i,'source_url']]
    if len(numComms) == 2.0:
        sources.at[i,'color'] = 'g'
    elif len(numComms) == 1.0:
        if numComms.iloc[0]['community'] == '0':
            sources.at[i,'color'] = 'y'
        if numComms.iloc[0]['community'] == '1':
            sources.at[i,'color'] = 'b'
    else:
        sources.at[i,'color'] = 'w'
sources
# Out:
#                         source_name       source_type  \
# 0         entertainment.abs-cbn.com  external website
# 1                www.gmanetwork.com  external website
# 2                   526965450801338          facebook
# 3                      Mochablogger          facebook
# 6      pinoytrending.altervista.org  external website
# ...                             ...               ...
# 40424                       PRO7PNP          facebook
# 40447     www.westernjournalism.com  external website
# 40449           www.navhindtimes.in  external website
# 40451          ktsmradio.iheart.com  external website
# 40467                  304981108326          facebook
#
#                              source_url color
# 0             entertainment.abs-cbn.com     y
# 1                    www.gmanetwork.com     y
# 2      www.facebook.com/526965450801338     y
# 3         www.facebook.com/Mochablogger     y
# 6          pinoytrending.altervista.org     y
# ...                                 ...   ...
# 40424          www.facebook.com/PRO7PNP     w
# 40447         www.westernjournalism.com     w
# 40449               www.navhindtimes.in     w
# 40451              ktsmradio.iheart.com     w
# 40467     www.facebook.com/304981108326     w
#
# [7357 rows x 4 columns]

# %%
# Get all unique linkers from master
linkers = master.drop_duplicates(subset=['linker_url'])[["linker_name","linker_type","linker_url"]]
linkers
# Out:
#                           linker_name linker_type  \
# 0                             ABS-CBN        page
# 1                            GMA News        page
# 2             PSSAP Underground Media        page
# 3                     MOCHA USON BLOG        page
# 7                        ABS-CBN News        page
# ...                               ...         ...
# 40460  Save Our Schools; The Movement        page
# 40461            Network For Progress        page
# 40462         Search Engine Marketing       group
# 40466                        Fox News        page
# 40467     Coffee Party USA - Portland        page
#
#                                  linker_url
# 0            www.facebook.com/ABSCBNnetwork
# 1                  www.facebook.com/gmanews
# 2          www.facebook.com/526965450801338
# 3             www.facebook.com/Mochablogger
# 7               www.facebook.com/abscbnNEWS
# ...                                     ...
# 40460      www.facebook.com/162470283812585
# 40461   www.facebook.com/networkforprogress
# 40462    www.facebook.com/groups/2211885060
# 40466              www.facebook.com/FoxNews
# 40467  www.facebook.com/CoffeePartyPortland
#
# [7059 rows x 3 columns]

# %%
# For each linker, get all sources connected to it.
# Then, lookup each source in the root_sources_concat table.
# Group these sources by how many times the linker shared it. (times_shared)
# Each source will have an assigned color (from the sources table)
for i in linkers.index.tolist():
    linker_sources = (
        master
            [master['linker_url'] == linkers.at[i,'linker_url']]
            .groupby('source_url')
            .agg(times_shared=('source_url','count'))
            .sort_values(by='times_shared',ascending=False)
            .reset_index()
    )
    linker_sources['color'] = linker_sources['source_url'].apply(
        lambda x: sources.set_index('source_url').at[x,'color']
    )
    try:
        color_tally = linker_sources.groupby('color').agg(c=('times_shared','sum')).reset_index()
        finalColor = color_tally.at[color_tally['c'].idxmax(),'color']
    except:
        finalColor = 'w'
    linkers.at[i,'color'] = finalColor
linkers
# Out:
#                           linker_name linker_type  \
# 0                             ABS-CBN        page
# 1                            GMA News        page
# 2             PSSAP Underground Media        page
# 3                     MOCHA USON BLOG        page
# 7                        ABS-CBN News        page
# ...                               ...         ...
# 40460  Save Our Schools; The Movement        page
# 40461            Network For Progress        page
# 40462         Search Engine Marketing       group
# 40466                        Fox News        page
# 40467     Coffee Party USA - Portland        page
#
#                                  linker_url color
# 0            www.facebook.com/ABSCBNnetwork     w
# 1                  www.facebook.com/gmanews     y
# 2          www.facebook.com/526965450801338     y
# 3             www.facebook.com/Mochablogger     y
# 7               www.facebook.com/abscbnNEWS     y
# ...                                     ...   ...
# 40460      www.facebook.com/162470283812585     g
# 40461   www.facebook.com/networkforprogress     w
# 40462    www.facebook.com/groups/2211885060     y
# 40466              www.facebook.com/FoxNews     w
# 40467  www.facebook.com/CoffeePartyPortland     w
#
# [7059 rows x 4 columns]

# %%
# Concatenate the sources and linkers dataset, then rename some values for better visualizations
sources2 = sources.rename(columns={'source_name': 'name','source_type':'type','source_url':'url'})
sources2['type'] = ['source']*len(sources2)
sources2['size'] = sources2['url'].apply(lambda x: len(master[master['source_url'] == x]))
sources2['url'] = 'src_'+sources2['url']

linkers2 = linkers.rename(columns={'linker_name': 'name','linker_type':'type','linker_url':'url'})
linkers2['url'] = 'lnk_'+linkers2['url']
linkers2['type'] = ['linkers']*len(linkers2)
linkers2['size'] = [1]*len(linkers2)

allNodes = pd.concat([sources2,linkers2],ignore_index=True)
allNodes['finalColor'] = allNodes['type'] + allNodes['color']
allNodes = allNodes.drop_duplicates(subset=['url'])
allNodes['finalColor'] = allNodes['finalColor'].replace({
    'sourcew': 'No community (Source)',
    'sourcey': 'Community B (Source)',
    'sourceb': 'Community A (Source)',
    'sourceg': 'Community AB (Source)',
    'linkersw': 'No community (Sharer)',
    'linkersy': 'Community B (Sharer)',
    'linkersb': 'Community A (Sharer)',
    'linkersg': 'Community AB (Sharer)'
})
allNodes
# Out:
#                                  name     type  \
# 0           entertainment.abs-cbn.com   source
# 1                  www.gmanetwork.com   source
# 2                     526965450801338   source
# 3                        Mochablogger   source
# 4        pinoytrending.altervista.org   source
# ...                               ...      ...
# 14411  Save Our Schools; The Movement  linkers
# 14412            Network For Progress  linkers
# 14413         Search Engine Marketing  linkers
# 14414                        Fox News  linkers
# 14415     Coffee Party USA - Portland  linkers
#
#                                             url color  size  \
# 0                 src_entertainment.abs-cbn.com     y     9
# 1                        src_www.gmanetwork.com     y   336
# 2          src_www.facebook.com/526965450801338     y   738
# 3             src_www.facebook.com/Mochablogger     y   767
# 4              src_pinoytrending.altervista.org     y    62
# ...                                         ...   ...   ...
# 14411      lnk_www.facebook.com/162470283812585     g     1
# 14412   lnk_www.facebook.com/networkforprogress     w     1
# 14413    lnk_www.facebook.com/groups/2211885060     y     1
# 14414              lnk_www.facebook.com/FoxNews     w     1
# 14415  lnk_www.facebook.com/CoffeePartyPortland     w     1
#
#                   finalColor
# 0       Community B (Source)
# 1       Community B (Source)
# 2       Community B (Source)
# 3       Community B (Source)
# 4       Community B (Source)
# ...                      ...
# 14411  Community AB (Sharer)
# 14412  No community (Sharer)
# 14413   Community B (Sharer)
# 14414  No community (Sharer)
# 14415  No community (Sharer)
#
# [14416 rows x 6 columns]

# %%
# Generate the links of the agent map
agentLinks = []
for i in master.index.tolist():
    agentLink = {
        'sourceUrl': 'src_' + str(master.at[i,'source_url']),
        'linkerUrl': 'lnk_' + str(master.at[i,'linker_url']),
        'linkId': str(master.at[i,'source_url']) + str(master.at[i,'linker_url'])
    }
    agentLinks.append(agentLink)

agentMap = (
    pd.DataFrame(agentLinks)
    .groupby(['sourceUrl','linkerUrl','linkId'])
    .agg(linkStrength=('linkId','count'))
    .sort_values(by='linkStrength',ascending=False)
    .reset_index()
)
agentMap
# Out:
#                                          sourceUrl  \
# 0      src_www.facebook.com/groups/538773259559791
# 1      src_www.facebook.com/groups/308734279321570
# 2         src_www.facebook.com/IamAgainstPaidMedia
# 3                             src_www.philnews.xyz
# 4        src_www.facebook.com/boycottabscbnstation
# ...                                            ...
# 21027                                     src_t.co
# 21028                                     src_t.co
# 21029                                     src_t.co
# 21030                                     src_t.co
# 21031                             src_zelezny.link
#
#                                                linkerUrl  \
# 0                                                lnk_nan
# 1                                                lnk_nan
# 2                lnk_www.facebook.com/aapnomore4aamaadmi
# 3                  lnk_www.facebook.com/SecMartinAndanar
# 4            lnk_www.facebook.com/groups/538773259559791
# ...                                                  ...
# 21027               lnk_www.facebook.com/605782269475008
# 21028                lnk_www.facebook.com/BabyfaceBenji
# 21029  lnk_www.facebook.com/EatingDisordersAwareness....
# 21030                    lnk_www.facebook.com/HugotWords
# 21031                 lnk_www.facebook.com/ZeleznyLukasz
#
#                                                   linkId  linkStrength
# 0             www.facebook.com/groups/538773259559791nan           383
# 1             www.facebook.com/groups/308734279321570nan           289
# 2      www.facebook.com/IamAgainstPaidMediawww.facebo...           216
# 3      www.philnews.xyzwww.facebook.com/SecMartinAndanar           165
# 4      www.facebook.com/boycottabscbnstationwww.faceb...           158
# ...                                                  ...           ...
# 21027               t.cowww.facebook.com/605782269475008             1
# 21028                t.cowww.facebook.com/BabyfaceBenji              1
# 21029  t.cowww.facebook.com/EatingDisordersAwareness....             1
# 21030                    t.cowww.facebook.com/HugotWords             1
# 21031         zelezny.linkwww.facebook.com/ZeleznyLukasz             1
#
# [21032 rows x 4 columns]

# %%
# Export agentMap and allNodes
agentMap.to_csv(f'results/{filename_base}-agent-map-color-coded-links.csv',index=False)
allNodes.to_csv(f'results/{filename_base}-agent-map-color-coded-nodes.csv',index=False)
