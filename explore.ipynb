# %%
import pandas as pd
import networkx as nx

# %%
filename = "data/rappler-oct-2021-scan-processed.csv"
df = pd.read_csv(
    filename,
    usecols=["linker_name","linker_type","linker_url","source_name","source_type","source_url"],
    dtype=str
)

# %%
df
# Out:
#       linker_type      linker_name                        linker_url  \
# 0            page          Rappler    www.facebook.com/rapplerdotcom
# 1            page      Nobel Prize       www.facebook.com/nobelprize
# 2            page     INQUIRER.net   www.facebook.com/inquirerdotnet
# 3            page      Nobel Prize       www.facebook.com/nobelprize
# 4            page          Rappler    www.facebook.com/rapplerdotcom
# ...           ...              ...                               ...
# 17405        page     Business Day  www.facebook.com/businessdaylive
# 17406        page       CWA Canada        www.facebook.com/cwacanada
# 17407        page       La Opinión      www.facebook.com/LaOpinionLA
# 17408        page  Global Exchange   www.facebook.com/GlobalExchange
# 17409        page       The Nation   www.facebook.com/thenationdaily
#
#             source_type             source_name  \
# 0              facebook           rapplerdotcom
# 1              facebook              nobelprize
# 2              facebook          inquirerdotnet
# 3              facebook              nobelprize
# 4              facebook           rapplerdotcom
# ...                 ...                     ...
# 17405  external website  www.businesslive.co.za
# 17406  external website             www.bbc.com
# 17407  external website           laopinion.com
# 17408  external website    www.democracynow.org
# 17409  external website           nation.com.pk
#
#                             source_url
# 0       www.facebook.com/rapplerdotcom
# 1          www.facebook.com/nobelprize
# 2      www.facebook.com/inquirerdotnet
# 3          www.facebook.com/nobelprize
# 4       www.facebook.com/rapplerdotcom
# ...                                ...
# 17405           www.businesslive.co.za
# 17406                      www.bbc.com
# 17407                    laopinion.com
# 17408             www.democracynow.org
# 17409                    nation.com.pk
#
# [17410 rows x 6 columns]

# %%
sources = df[["source_name","source_type","source_url"]].drop_duplicates(subset=['source_url'])
sources
# Out:
#                 source_name       source_type  \
# 0             rapplerdotcom          facebook
# 1                nobelprize          facebook
# 2            inquirerdotnet          facebook
# 5           StarImageArtist          facebook
# 8              philstarlife          facebook
# ...                     ...               ...
# 17397     MWWomenforJustice          facebook
# 17398  www.radiosantafe.com  external website
# 17404     www.ibtimes.co.in  external website
# 17407         laopinion.com  external website
# 17409         nation.com.pk  external website
#
#                                source_url
# 0          www.facebook.com/rapplerdotcom
# 1             www.facebook.com/nobelprize
# 2         www.facebook.com/inquirerdotnet
# 5        www.facebook.com/StarImageArtist
# 8           www.facebook.com/philstarlife
# ...                                   ...
# 17397  www.facebook.com/MWWomenforJustice
# 17398                www.radiosantafe.com
# 17404                   www.ibtimes.co.in
# 17407                       laopinion.com
# 17409                       nation.com.pk
#
# [3236 rows x 3 columns]

# %%
# Determine number of agents per source
hubs = pd.DataFrame()
for i in df.index.tolist():
    source = df.at[i,'source_url']
    dest = df.at[i,'linker_url']
    if source != dest:
        try:
            hubs.at[source,'connectors'] += 1
        except:
            hubs.at[source,'connectors'] = 1
hubs = hubs[ hubs['connectors'] > 20 ].sort_values(by='connectors',ascending=False).reset_index()
hubs = hubs[(~hubs['index'].isna()) & (hubs['index'] != 'bit.ly')]

# %%
hubs
# Out:
#                                                 index  connectors
# 0                      www.facebook.com/rapplerdotcom      3532.0
# 1                                          postly.app       376.0
# 2                                     www.rappler.com       329.0
# 3                         www.facebook.com/nobelprize       293.0
# 4             www.facebook.com/subagenbangonpilipinas       236.0
# ..                                                ...         ...
# 82  https://youtube.com/watch?v=jVe7aeVne4g&featur...        22.0
# 83                    www.facebook.com/CNNPhilippines        22.0
# 84                  www.facebook.com/1113650032052216        22.0
# 85  https://www.facebook.com/photo.php?fbid=422676...        21.0
# 86  https://www.facebook.com/photo.php?fbid=101589...        21.0
#
# [86 rows x 2 columns]

# %%
pd.merge(hubs,sources,left_on='index',right_on='source_url',how='left')
# Out:
#                                                 index  connectors  \
# 0                      www.facebook.com/rapplerdotcom      3532.0
# 1                                          postly.app       376.0
# 2                                     www.rappler.com       329.0
# 3                         www.facebook.com/nobelprize       293.0
# 4             www.facebook.com/subagenbangonpilipinas       236.0
# ..                                                ...         ...
# 81  https://youtube.com/watch?v=jVe7aeVne4g&featur...        22.0
# 82                    www.facebook.com/CNNPhilippines        22.0
# 83                  www.facebook.com/1113650032052216        22.0
# 84  https://www.facebook.com/photo.php?fbid=422676...        21.0
# 85  https://www.facebook.com/photo.php?fbid=101589...        21.0
#
#                                           source_name       source_type  \
# 0                                       rapplerdotcom          facebook
# 1                                          postly.app  external website
# 2                                     www.rappler.com  external website
# 3                                          nobelprize          facebook
# 4                              subagenbangonpilipinas          facebook
# ..                                                ...               ...
# 81  YouTube video: https://youtube.com/watch?v=jVe...           youtube
# 82                                     CNNPhilippines          facebook
# 83                                   1113650032052216          facebook
# 84                                 Facebook profile:           facebook
# 85                               Facebook profile: MJ          facebook
#
#                                            source_url
# 0                      www.facebook.com/rapplerdotcom
# 1                                          postly.app
# 2                                     www.rappler.com
# 3                         www.facebook.com/nobelprize
# 4             www.facebook.com/subagenbangonpilipinas
# ..                                                ...
# 81  https://youtube.com/watch?v=jVe7aeVne4g&featur...
# 82                    www.facebook.com/CNNPhilippines
# 83                  www.facebook.com/1113650032052216
# 84  https://www.facebook.com/photo.php?fbid=422676...
# 85  https://www.facebook.com/photo.php?fbid=101589...
#
# [86 rows x 5 columns]

# %%
def shared_audience(pages,posts,site_ind1,site_ind2,threshold=0):
    site1 = pages.loc[site_ind1,'index']
    site2 = pages.loc[site_ind2,'index']
    agents1 = set(list(posts[posts['source_name'] == site1]['linker_slug']))
    agents2 = set(list(posts[posts['source_name'] == site2]['linker_slug']))
    common_agents = agents1.intersection(agents2)

    if len(common_agents) >= threshold:
        return {"shared": True, "commons": len(common_agents) }
    else:
        return {"shared": False, "commons": len(common_agents) }

# %%
pages_df = hubs
num_pages = len(hubs)

links = []
commons = []
page_inds = pages_df.index.tolist()
pairs = list(itertools.combinations(page_inds,2))
counter = 0
for pair in pairs:
    total_pairs = num_pages*(num_pages-1)/2
    res = shared_audience(pages=pages_df,posts=df,site_ind1=pair[0],site_ind2=pair[1])
    link = res['shared']
    commons.append(res['commons'])
    if link == True:
        links.append({
            "site1": pages_df.loc[pair[0],'index'],
            "site2": pages_df.loc[pair[1],'index'],
            "link": res['commons']
        })
    counter+= 1
    if counter%1000 == 0:
        print(f"Processed {counter} of {total_pairs} pairs")
    if counter == total_pairs:
        print(f"Processed {counter} of {total_pairs} pairs")

links = pd.DataFrame(links)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'linker_slug'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13168/193269604.py in <module>
#       9 for pair in pairs:
#      10     total_pairs = num_pages*(num_pages-1)/2
# ---> 11     res = shared_audience(pages=pages_df,posts=df,site_ind1=pair[0],site_ind2=pair[1])
#      12     link = res['shared']
#      13     commons.append(res['commons'])
#
# ~\AppData\Local\Temp/ipykernel_13168/3821240278.py in shared_audience(pages, posts, site_ind1, site_ind2, threshold)
#       2     site1 = pages.loc[site_ind1,'index']
#       3     site2 = pages.loc[site_ind2,'index']
# ----> 4     agents1 = set(list(posts[posts['source_name'] == site1]['linker_slug']))
#       5     agents2 = set(list(posts[posts['source_name'] == site2]['linker_slug']))
#       6     common_agents = agents1.intersection(agents2)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'linker_slug'

# %%
links
# Out:
#                             site1                  site2  link
# 0                   rapplerdotcom       news.abs-cbn.com    49
# 1                   rapplerdotcom        www.rappler.com    59
# 2                   rapplerdotcom     www.gmanetwork.com    32
# 3                   rapplerdotcom        News5Everywhere    42
# 4                   rapplerdotcom  newsinfo.inquirer.net    39
# ...                           ...                    ...   ...
# 2623         www.bulgaronline.com  www.getrealpundit.com     1
# 2624         www.bulgaronline.com       www.idntimes.com     0
# 2625  Facebook profile: Leon Junn  www.getrealpundit.com     0
# 2626  Facebook profile: Leon Junn       www.idntimes.com     0
# 2627        www.getrealpundit.com       www.idntimes.com     0
#
# [2628 rows x 3 columns]
